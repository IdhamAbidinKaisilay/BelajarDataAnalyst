# %% [markdown]
# <a href="https://colab.research.google.com/github/IdhamAbidinKaisilay/BelajarDataAnalyst/blob/main/fungsi_pada_Data_Nilai_Series_dan_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Menggunakan fungsi pada Data/Nilai Series dan DataFrame

# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
data = {
    'nama':['Ansar', 'Usman', 'Hesti', 'Alex', 'Indra'],
    'gaji_dolar' : [5300, 2300, 10500, 4000, 15000],
    'bonus':[100,200, 300, 400, 500],
    'pengalaman':[1,2,3,4,5]
}

df = pd.DataFrame(data)
df
# Out:
#     nama  gaji_dolar  bonus  pengalaman
# 0  Ansar        5300    100           1
# 1  Usman        2300    200           2
# 2  Hesti       10500    300           3
# 3   Alex        4000    400           4
# 4  Indra       15000    500           5

# %%
#menambahkan fungsi ke series
def status(gaji):
  if gaji >= 10000:
    return 'Manager'
  else:
    return 'Staff'

# %%
df['status'] = df['gaji_dolar'].apply(status)
# membuat kolom baru bernama 'status'
# setiap elemen kolom 'gaji_dolar' diproses oleh fungsi status(gaji)
# hasilnya disimpan di kolom 'status'

# %%
df
# Out:
#     nama  gaji_dolar  bonus  pengalaman   status
# 0  Ansar        5300    100           1    Staff
# 1  Usman        2300    200           2    Staff
# 2  Hesti       10500    300           3  Manager
# 3   Alex        4000    400           4    Staff
# 4  Indra       15000    500           5  Manager

# %%
#menambahkan fungsi ke dataframe
def fasilitas(df):
  if df['status'] == 'Manager':
    return 'Mobil Dinas'
  else:
    return 'Motor Dinas'

# %%
df['fasilitas'] = df.apply(fasilitas, axis=1)
# membuat kolom baru bernama 'fasilitas'
# apply dengan axis=1 artinya fungsi dijalankan untuk setiap baris (row)
# fungsi fasilitas menerima 1 baris dataframe sebagai input
# lalu menghasilkan nilai 'Mobil Dinas' atau 'Motor Dinas'

# %%
df
# Out:
#     nama  gaji_dolar  bonus  pengalaman   status    fasilitas
# 0  Ansar        5300    100           1    Staff  Motor Dinas
# 1  Usman        2300    200           2    Staff  Motor Dinas
# 2  Hesti       10500    300           3  Manager  Mobil Dinas
# 3   Alex        4000    400           4    Staff  Motor Dinas
# 4  Indra       15000    500           5  Manager  Mobil Dinas

# %%
def fasilitas_lain(df):
  if df['status'] == 'Manager':
    if df['pengalaman'] > 4:
      return 'Rumah Dinas'
    else:
      return 'Tidak ada'
  else:
    return 'Tidak ada'

# %%
df['fasilitas_lain'] = df.apply(fasilitas_lain, axis=1)
# membuat kolom baru bernama 'fasilitas_lain'
# apply dengan axis=1 artinya fungsi dijalankan per baris dataframe
# jika status Manager dan pengalaman > 4, hasil 'Rumah Dinas'
# jika tidak, hasil 'Tidak ada'

# %%
df
# Out:
#     nama  gaji_dolar  bonus  pengalaman   status    fasilitas fasilitas_lain
# 0  Ansar        5300    100           1    Staff  Motor Dinas      Tidak ada
# 1  Usman        2300    200           2    Staff  Motor Dinas      Tidak ada
# 2  Hesti       10500    300           3  Manager  Mobil Dinas      Tidak ada
# 3   Alex        4000    400           4    Staff  Motor Dinas      Tidak ada
# 4  Indra       15000    500           5  Manager  Mobil Dinas    Rumah Dinas

# %% [markdown]
# Quiz

# %%
df_quiz = {
    'Name': ['Jack', 'Riti', 'Vikas', 'Neelu', 'John', 'Mike'],
    'Age': [34,30,31,32,16,17],
    'Country': ['Australia', 'India', 'India', 'India', 'US', 'US']
}
df_index = ['a', 'b', 'c', 'd', 'e', 'f']
worker = pd.DataFrame(df_quiz, index=df_index)
worker
# Out:
#     Name  Age    Country
# a   Jack   34  Australia
# b   Riti   30      India
# c  Vikas   31      India
# d  Neelu   32      India
# e   John   16         US
# f   Mike   17         US

# %% [markdown]
# def year_to_month(age_year):
#    return age_year*12
#
# Perhatikan dataframe dan fungsi diatas, jika saya ingin membuat kolom baru age_months, kode yang tepat adalah?

# %%
def year_to_month(age_year):
   return age_year*12

# %%
worker['age_months'] = worker['Age'].apply(year_to_month)
worker
# Out:
#     Name  Age    Country  age_months
# a   Jack   34  Australia         408
# b   Riti   30      India         360
# c  Vikas   31      India         372
# d  Neelu   32      India         384
# e   John   16         US         192
# f   Mike   17         US         204
