# %% [markdown]
# <a href="https://colab.research.google.com/github/IdhamAbidinKaisilay/BelajarDataAnalyst/blob/main/Mengurutkan_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Data Analyst 2025 + SQL + Excel/Section 9 [MISSION 6] Pandas Analisis Data/STEM_Salaries.csv'
df = pd.read_csv(path)
df.sample(3)
# Out:
#                 timestamp               company  \
# 53630    6/7/2021 4:09:48  The D. E. Shaw Group
# 34397  11/2/2020 13:00:02                 Tesla
# 39753  1/19/2021 12:33:33             Accenture
#
#                                level              title  \
# 53630                             MT  Software Engineer
# 34397                Senior Engineer  Software Engineer
# 39753  Advanced Application Engineer  Software Engineer
#
#        totalyearlycompensation              location  yearsofexperience  \
# 53630                    45000  Hyderabad, TS, India                2.0
# 34397                   230000     San Francisco, CA               11.0
# 39753                    85000      Philadelphia, PA                0.0
#
#        yearsatcompany                         tag  basesalary  ...  \
# 53630             2.0  API Development (Back-End)     36000.0  ...
# 34397             1.0      Site Reliability (SRE)    180000.0  ...
# ...

# %%
pd.options.display.max_columns = None
df.sample(3)
# Out:
#                  timestamp  company  level                         title  \
# 11911  10/10/2019 18:21:54  Workday     P2             Software Engineer
# 62401   3/29/2018 14:22:33   Amazon  SDE 3             Software Engineer
# 38379   12/31/2020 0:55:03   Amazon     L4  Software Engineering Manager
#
#        totalyearlycompensation           location  yearsofexperience  \
# 11911                   125000        Boulder, CO                3.0
# 62401                   315000        Seattle, WA               22.0
# 38379                   188000  San Francisco, CA               10.0
#
#        yearsatcompany                         tag  basesalary  \
# 11911             1.0  API Development (Back-End)     93000.0
# 62401             2.0                         NaN    160000.0
# 38379            10.0                        Data    150000.0
#
#        stockgrantvalue    bonus gender otherdetails  cityid  dmaid  rowNumber  \
# ...

# %%
df.sort_values(by='basesalary', ascending=False)
# Out:
#                 timestamp      company                     level  \
# 62351   1/5/2018 13:59:58    Microsoft                        64
# 61851   6/12/2018 5:04:06  Squarespace                  Senior I
# 45054  3/15/2021 13:26:40          PwC       Partner / Principal
# 56175  6/30/2021 15:26:10      Netflix  Senior Software Engineer
# 57701  7/14/2021 16:23:01      Netflix  Senior Software Engineer
# ...                   ...          ...                       ...
# 5959   4/21/2019 17:11:56    Microsoft                        61
# 5958   4/21/2019 16:33:17       Amazon                     SDE I
# 5955   4/21/2019 13:54:29       Amazon                        L7
# 5953   4/21/2019 12:58:27     Facebook                        E3
# 3523     1/5/2019 4:17:34       Amazon                   SDE III
#
#                               title  totalyearlycompensation  \
# 62351               Product Manager                   250000
# ...

# %%
df.sort_values(by=['title', 'basesalary'], ascending=True)[['title','basesalary', 'level', 'company']]
# Out:
#                            title  basesalary                          level  \
# 4393            Business Analyst         0.0                 Vice President
# 6866            Business Analyst         0.0                            C01
# 7697            Business Analyst         0.0                         Junior
# 30149           Business Analyst      9000.0                      Associate
# 38897           Business Analyst     10000.0                             L1
# ...                          ...         ...                            ...
# 52003  Technical Program Manager    300000.0                         PSG 27
# 54713  Technical Program Manager    300000.0                             L8
# 57932  Technical Program Manager    300000.0                       Grade 11
# 40228  Technical Program Manager    350000.0                       Director
# 41010  Technical Program Manager    430000.0  Only one level across Netflix
#
#                        company
# ...

# %%
df.set_index('title', inplace=True)

# %%
df.sort_index()
# Out:
#                                     timestamp                    company  \
# title
# Business Analyst           7/18/2020 11:37:18  Tata Consultancy Services
# Business Analyst           2/10/2021 15:06:54                  Qualtrics
# Business Analyst           11/17/2020 6:29:19       Veritas Technologies
# Business Analyst           6/26/2020 10:18:30                      Chase
# Business Analyst           9/30/2020 12:09:06                     Amazon
# ...                                       ...                        ...
# Technical Program Manager  5/16/2021 19:10:44            Lockheed Martin
# Technical Program Manager   8/13/2021 7:27:26                        HPE
# Technical Program Manager   6/6/2020 14:29:20                     Amazon
# Technical Program Manager   2/13/2021 0:17:44                       AT&T
# Technical Program Manager   4/6/2021 16:32:56                     PayPal
#
#                                level  totalyearlycompensation  \
# title
# ...
