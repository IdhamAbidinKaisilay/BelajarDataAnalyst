# %% [markdown]
# <a href="https://colab.research.google.com/github/IdhamAbidinKaisilay/BelajarDataAnalyst/blob/main/Pie_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pie chart sederhana

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use('tableau-colorblind10')
path='/content/drive/MyDrive/Data Analyst 2025 + SQL + Excel/Section 13 Matplotlib: BPS, Kaggle dan Pie Chart/shanghai_ranking_2024.csv'
df=pd.read_csv(path)

# pd.options.display.max_rows=None
df.iloc[0:10]
# df.head()
# Out:
#   Rank                              University_Name National/Regional Rank  \
# 0    1                           Harvard University                      1
# 1    2                          Stanford University                      2
# 2    3  Massachusetts Institute of Technology (MIT)                      3
# 3    4                      University of Cambridge                      1
# 4    5           University of California, Berkeley                      4
# 5    6                         University of Oxford                      2
# 6    7                         Princeton University                      5
# 7    8           California Institute of Technology                    6-7
# 8    8                          Columbia University                    6-7
# 9   10                        University of Chicago                      8
#
#    Alumni  Award   Hici    N&S    PUB    PCP
# 0   100.0   97.1  100.0  100.0  100.0   85.7
# 1    45.3   88.1   73.1   83.9   73.1   59.6
# ...

# %%
target = 'Massachusetts Institute of Technology (MIT)'
filter = df['University_Name'] == target
data = df[filter].iloc[0][3:]
label = df[filter].iloc[0][3:].index

plt.pie(data, labels=label)

plt.title(f"Nilai Indikator Shanghai Ranking \ndi {target}")

plt.show()

# %% [markdown]
# #Modifikasi Pie Chart

# %%
target = 'Massachusetts Institute of Technology (MIT)'
filter = df['University_Name'] == target
data = df[filter].iloc[0][3:]
label = df[filter].iloc[0][3:].index

warna = ['gold', '#DDFF51', 'lightcoral', 'lightskyblue', 'pink', '#00AAEE']
param_explode = [0, 0, 0, 0, 0, 0.2]

plt.pie(data, labels=label,
        colors=warna, autopct="%.1f%%",
        pctdistance=0.7, labeldistance=1.1,
        shadow=True, explode= param_explode)

plt.title(f"Nilai Indikator Shanghai Ranking \ndi {target}")

plt.show()
